# %% [markdown]
# <a href="https://colab.research.google.com/github/vikramreddy2002/pandas_vis/blob/main/colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv("Salaries.csv")
print(df)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.isna().count()
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
pd.set_option('display.max_rows',None)

# %%
df.isna()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
df.isna().count()
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
df.isna().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
# 5          Prof
# 6     AssocProf
# 7          Prof
# 8          Prof
# 9          Prof
# 10         Prof
# 11         Prof
# 12     AsstProf
# 13         Prof
# 14         Prof
# 15         Prof
# 16     AsstProf
# 17     AsstProf
# 18         Prof
# 19         Prof
# 20     AsstProf
# 21         Prof
# 22     AsstProf
# 23     AsstProf
# 24         Prof
# 25         Prof
# 26         Prof
# 27         Prof
# 28     AsstProf
# 29         Prof
# 30    AssocProf
# 31         Prof
# 32         Prof
# 33         Prof
# 34    AssocProf
# 35         Prof
# 36         Prof
# 37         Prof
# 38     AsstProf
# 39         Prof
# 40         Prof
# 41    AssocProf
# 42     AsstProf
# 43     AsstProf
# 44         Prof
# 45         Prof
# 46     AsstProf
# 47    AssocProf
# 48         Prof
# 49         Prof
# 50     AsstProf
# 51         Prof
# 52         Prof
# 53     AsstProf
# 54    AssocProf
# ...

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427907

# %%
df['salary'].std()
# Out:
# 28293.66102226417

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].max()
# Out:
# 186960

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df[['salary','service']]
# Out:
#     salary  service
# 0   186960       49
# 1    93000        6
# 2   110515       20
# 3   131205       31
# 4   104800       18
# 5   122400       20
# 6    81285       17
# 7   126300       18
# 8    94350       19
# 9    57800       51
# 10  128250       33
# 11  134778       23
# 12   88000        0
# 13  162200       33
# 14  153750       19
# 15  150480        3
# 16   75044        3
# 17   92000        0
# 18  107300        7
# 19  150500       27
# 20   92000        4
# 21  103106       30
# 22   73000        2
# 23   85000        0
# 24   91100       23
# 25   99418       31
# 26  148750       19
# 27  155865       43
# 28   91300        2
# 29  123683       20
# 30  107008        7
# 31  155750       21
# 32  103275       19
# 33  120000       18
# 34  119800        8
# 35  126933       23
# 36  146856       45
# 37  102000        8
# 38   91000        3
# 39  129000       18
# 40  137000       36
# 41   74830        8
# 42   80225        2
# 43   77000        0
# ...

# %%
df['salary']>15000
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# 56    True
# 57    True
# 58    True
# 59    True
# 60    True
# 61    True
# 62    True
# 63    True
# 64    True
# 65    True
# 66    True
# 67    True
# 68    True
# 69    True
# 70    True
# 71    True
# 72    True
# 73    True
# 74    True
# 75    True
# ...

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:5,:]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
df.kurt(numeric_only=True)
# Out:
# phd        0.042504
# service    0.608981
# salary    -0.401713
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
plt.hist(df['salary'])
plt.xlabel('salary')
plt.ylabel('count')
plt.title('histogram')
plt.show()

# %%
sn.histplot(df['salary'])
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
df.kurtosis(numeric_only=True)
# Out:
# phd        0.042504
# service    0.608981
# salary    -0.401713
# dtype: float64

# %%
sn.histplot(df['service'])
# Out:
# <Axes: xlabel='service', ylabel='Count'>

# %%
plt.figure(figsize=(10,3))
sn.histplot(df['service'])
# Out:
# <Axes: xlabel='service', ylabel='Count'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

df=pd.read_csv('Universities.csv')

# %%
df.mean(numeric_only=True)
# Out:
# SAT          1266.44
# Top10          76.48
# Accept         39.20
# SFRatio        12.72
# Expenses    27388.00
# GradRate       86.72
# dtype: float64

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
df.skew(numeric_only=True)
# Out:
# SAT        -0.950910
# Top10      -1.219756
# Accept      0.867538
# SFRatio     1.120719
# Expenses    0.852350
# GradRate   -0.999521
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
df.min()
# Out:
# Univ        Brown
# SAT          1005
# Top10          28
# Accept         14
# SFRatio         6
# Expenses     8704
# GradRate       67
# dtype: object

# %%
df.max()
# Out:
# Univ         Yale
# SAT          1415
# Top10         100
# Accept         90
# SFRatio        25
# Expenses    63575
# GradRate       97
# dtype: object

# %%
df.median(numeric_only=True)
# Out:
# SAT          1285.0
# Top10          81.0
# Accept         36.0
# SFRatio        12.0
# Expenses    27553.0
# GradRate       90.0
# dtype: float64

# %%
df.mode(numeric_only=True).count()
# Out:
# SAT          4
# Top10        5
# Accept       4
# SFRatio      3
# Expenses    25
# GradRate     1
# dtype: int64

# %%
df.isna().count()
# Out:
# Univ        25
# SAT         25
# Top10       25
# Accept      25
# SFRatio     25
# Expenses    25
# GradRate    25
# dtype: int64

# %%
plt.hist(df['SAT'])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['SAT'])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
sn.histplot(df['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %%
df['SAT'].skew()
# Out:
# -0.9509096057089894

# %%
df['SAT'].kurtosis()
# Out:
# 0.3551223727674433

# %%
plt.plot(df['SAT'],df['Accept'],'bo')
plt.xlabel('SAT')
plt.ylabel('accept')
plt.title('scatter')
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
sn.pairplot(df)

# %%
import warnings
warnings.filterwarnings('ignore')

sn.pairplot(df.iloc[:,1:3])

# %%
sn.distplot(df['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Density'>

# %%
plt.boxplot(df['SAT'])
plt.show()

# %%
plt.boxplot(df['SAT'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b79ad566fb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7b79ad5654b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7b79ad565d50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b79ad567ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b79ad567c40>],
#  'means': []}

# %%
g
